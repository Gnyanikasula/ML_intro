# %% [markdown]
# # Intro Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot()
plt.show()

# %%
plt.plot([1,2,3]);

# %%
x =[1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# 1 st method
fig = plt.figure() #create a figure
ax = fig.add_subplot()
plt.show()

# %%
# 2 nd method
fig = plt.figure # create a fig
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) # add some data
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 # 2 nd method
#       2 fig = plt.figure # create a fig
# ----> 3 ax = fig.add_axes([1,1,1,1])
#       4 ax.plot(x,y) # add some data
#       5 plt.show()
#
# AttributeError: 'function' object has no attribute 'add_axes'

# %%
# 3rd method (Recommended)
fig,ax = plt.subplots()
ax.plot(x,y); #add some data

# %%
fig, ax = plt.subplots()
ax.plot(x,[50,100,150]);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 fig, ax = plt.subplots()
# ----> 2 ax.plot(x,[50,100,150])
#
# File ~\Desktop\sample_project\env\lib\site-packages\matplotlib\axes\_axes.py:1662, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1419 """
#    1420 Plot y versus x as lines and/or markers.
#    1421
#    (...)
#    1659 (``'green'``) or hex strings (``'#008000'``).
#    1660 """
#    1661 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1662 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1663 for line in lines:
#    1664     self.add_line(line)
#
# File ~\Desktop\sample_project\env\lib\site-packages\matplotlib\axes\_base.py:311, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     309     this += args[0],
#     310     args = args[1:]
# --> 311 yield from self._plot_args(
# ...

# %%
type(fig),type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# # matplotlib eaxaple workflow

# %%
# 0. Import matplotlib and get it ready for plotting in jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

#2.Setplot
fig ,ax = plt.subplots(figsize=(10,10)) #(widhth , Height)
# 3. plot data
ax.plot(x,y)
# 4.customize plot
ax.set(title = "Simple plot",
      xlabel = "Xaxis",
      ylabel = "Yaxis")
# 5. Save & Show (You save the whole figure)
fig.savefig("images/sample_plot.png")

# %% [markdown]
# ## Making figure with numpy array
# we want
# * Line plot
# * Sactter plot
# * Bar plot
# * Histogram
# * Subplots

# %%
import numpy as np

# %%
x = np.linspace(0,10,100)

# %%
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig ,ax = plt.subplots()
ax.plot(x,x**2)

# %%
# Use same data for scalar plot
fig,ax = plt.subplots()
ax.scatter(x,np.exp(x))

# %%
# Another scatter plot
fig ,ax = plt.subplots()
ax.scatter(x,np.sin(x))

# %%
# Make a plot from a dictionary
nutbutterprices = {"Almond butter":10,
                  "Peanut butter":8,
                  "Cashew bytter":12}
fig,ax = plt.subplots()
ax.bar(nutbutterprices.keys(),nutbutterprices.values())
ax.set(title = "Butter prices",
      ylabel = "Pries");

# %%
fig,ax = plt.subplots()
ax.barh(list(nutbutterprices.keys()),list(nutbutterprices.values()))
# Out:
# <BarContainer object of 3 artists>

# %%
# make some data histogram
x = np.random.randn(1000)
fig ,ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ##  Two options for subplots

# %%
#Subplot option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x/2)
ax2.scatter(np.random.random(10),np.random.random(10));
ax3.bar(nutbutterprices.keys(),nutbutterprices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option2
fig,ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
# Plot to each different index
ax[0,0].plot(x,x/2);
ax[0,1].scatter(np.random.random(10),np.random.random(10));
ax[1,0].bar(nutbutterprices.keys(),nutbutterprices.values());
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas data Fram

# %%
import pandas as pd

# %%
#Make a dataframe
carsales= pd.read_csv("car-sales.csv")
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
ts = pd.Series(np.random.randn(1000),index = pd.date_range("1/1/2023",periods=1000))

# %%
ts
# Out:
# 2023-01-01    0.786917
# 2023-01-02    0.769621
# 2023-01-03    0.789510
# 2023-01-04   -0.350992
# 2023-01-05    0.366767
#                 ...
# 2025-09-22    0.082258
# 2025-09-23   -0.621222
# 2025-09-24   -0.133539
# 2025-09-25   -0.063430
# 2025-09-26   -0.179646
# Freq: D, Length: 1000, dtype: float64

# %%
ts = ts.cumsum()
ts.plot()
# Out:
# <AxesSubplot: >

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
carsales['Price'] = carsales['Price'].replace('[\$\,\.]', '', regex=True).astype(str)
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
carsales['Price']=carsales['Price'].str[:-2]
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
carsales["Sales Date"] = pd.date_range("1/1/2023",periods = len(carsales))
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date
# 0  Toyota  White         150043      4   4000 2023-01-01
# 1   Honda    Red          87899      4   5000 2023-01-02
# 2  Toyota   Blue          32549      3   7000 2023-01-03
# 3     BMW  Black          11179      5  22000 2023-01-04
# 4  Nissan  White         213095      4   3500 2023-01-05
# 5  Toyota  Green          99213      4   4500 2023-01-06
# 6   Honda   Blue          45698      4   7500 2023-01-07
# 7   Honda   Blue          54738      4   7000 2023-01-08
# 8  Toyota  White          60000      4   6250 2023-01-09
# 9  Nissan  White          31600      4   9700 2023-01-10

# %%
carsales["Total Sales"] = carsales["Price"].astype(int).cumsum()
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
type(carsales["Total Sales"][0]),type(carsales["Price"][0])
# Out:
# (numpy.int32, str)

# %%
# Lets plot totalsales
carsales.plot(x="Sales Date",y="Total Sales");

# %%
# Reassign Price column to int
carsales["Price"] = carsales["Price"].astype(int)
carsales.plot(x="Odometer (KM)",y="Price",kind="scatter");

# %%
# How about a bar Graph
x = np.random.rand(10,4)
x

# Turn it into a dataFrame
df=pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.870634  0.714906  0.053380  0.580106
# 1  0.884532  0.809891  0.964663  0.877716
# 2  0.685718  0.308925  0.163280  0.026606
# 3  0.062390  0.662858  0.839953  0.188980
# 4  0.494640  0.939870  0.271469  0.074428
# 5  0.114292  0.800872  0.840086  0.183984
# 6  0.972833  0.836162  0.515017  0.789142
# 7  0.902416  0.982588  0.845660  0.314943
# 8  0.967050  0.966185  0.718199  0.345732
# 9  0.623904  0.612827  0.121705  0.080837

# %%
df.plot.bar();

# %%
df.plot(kind="bar");

# %%
carsales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price Sales Date  Total Sales
# 0  Toyota  White         150043      4   4000 2023-01-01         4000
# 1   Honda    Red          87899      4   5000 2023-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2023-01-03        16000
# 3     BMW  Black          11179      5  22000 2023-01-04        38000
# 4  Nissan  White         213095      4   3500 2023-01-05        41500
# 5  Toyota  Green          99213      4   4500 2023-01-06        46000
# 6   Honda   Blue          45698      4   7500 2023-01-07        53500
# 7   Honda   Blue          54738      4   7000 2023-01-08        60500
# 8  Toyota  White          60000      4   6250 2023-01-09        66750
# 9  Nissan  White          31600      4   9700 2023-01-10        76450

# %%
carsales.plot.bar()
# Out:
# <AxesSubplot: >

# %%
carsales.plot(x="Make",y="Odometer (KM)",kind="bar")
# Out:
# <AxesSubplot: xlabel='Make'>

# %%
# How about histograms
carsales["Odometer (KM)"].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
carsales["Odometer (KM)"].plot(kind="hist")
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
carsales["Odometer (KM)"].plot.hist(bins=10)
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
# Let's Try on another data set
heartdis = pd.read_csv("heart-disease.csv")
heartdis.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
#Create a histogram
heartdis["age"].plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
heartdis.plot.hist(figsize=(10,30),subplots=True);

# %% [markdown]
# ### Which one is recommended (pyplot vs matplotlib OO Method )?
# * When plotting something quickly,okay to use the pyplot method
# * When plotting sth more advanced , use th OO method

# %%
heartdis.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over50 = heartdis[heartdis["age"]>50]
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# pyplot
over50.plot(kind="scatter",x='age',y='chol',c='target');

# %%
# OO method
fix,ax = plt.subplots(figsize=(10,6))
over50.plot(kind='scatter',x='age',y='chol',c='target',ax=ax);
# ax.set_xlim([45,100])

# %%
# OO method from scratch
fix,ax = plt.subplots(figsize=(10,6))
# plot the data
scatter = ax.scatter(x=over50["age"],y=over50["chol"],c=over50["target"]);
# Customize
ax.set(title = "Heart Disease and Cholestrol Levels",
      xlabel = "Age",
      ylabel="Cholestrol");
# ADD a legend
ax.legend(*scatter.legend_elements(),title="Target")
#Add a horizontal line
ax.axhline(over50["chol"].mean(),
           linestyle='--')

# %%
over50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# Subplot of chol,age,thalch
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                           sharex=True)
# Add data to ax0
scatter = ax0.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"])
ax0.set(title="Heart Disease and Cholestrol levels",
       ylabel='Cholestrol')
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over50["chol"].mean(),
           linestyle='--')

# Add data to ax1
scatter = ax1.scatter(x=over50["age"],
                     y=over50["thalach"],
                     c=over50["target"])
ax1.set(title="Heart Disease and Max Heart rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over50["thalach"].mean(),
           linestyle='--');


fig.suptitle("Heart Disease Analysis",fontsize=16,fontweight="bold");

# %% [markdown]
# ## Costomizing Matplotlib plots and getting stylish

# %%
# See the different styles available
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
carsales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# %%
carsales["Price"].plot();

# %%
plt.style.use('seaborn-v0_8')
carsales["Price"].plot();

# %%
carsales.plot(x='Odometer (KM)',y="Price",kind="scatter");

# %%
plt.style.use('ggplot')
carsales["Price"].plot();

# %%
# Create some data
x=np.random.randn(10,4)
x
# Out:
# array([[ 0.39244871,  2.22581324, -1.25084776, -1.58300727],
#        [ 0.28947773, -0.33805667, -1.24373694, -1.44656264],
#        [-2.28069835,  1.05384611,  2.16116149, -0.87872986],
#        [-1.08155986,  0.31073119, -0.64970973,  0.03633612],
#        [ 1.46538188, -0.73990861,  0.58328526, -0.82928097],
#        [-0.92169011,  0.48897954, -1.60889981, -1.18755154],
#        [-0.54650265,  1.83221244,  1.89231033,  0.2882933 ],
#        [-1.06764094,  0.84496521, -0.73901512,  1.13166651],
#        [-0.29130503, -0.04797898, -1.57920424, -0.12986066],
#        [ 1.8268708 , -0.03570094, -0.41404724, -0.37232929]])

# %%
df = pd.DataFrame(x,columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  0.392449  2.225813 -1.250848 -1.583007
# 1  0.289478 -0.338057 -1.243737 -1.446563
# 2 -2.280698  1.053846  2.161161 -0.878730
# 3 -1.081560  0.310731 -0.649710  0.036336
# 4  1.465382 -0.739909  0.583285 -0.829281
# 5 -0.921690  0.488980 -1.608900 -1.187552
# 6 -0.546503  1.832212  1.892310  0.288293
# 7 -1.067641  0.844965 -0.739015  1.131667
# 8 -0.291305 -0.047979 -1.579204 -0.129861
# 9  1.826871 -0.035701 -0.414047 -0.372329

# %%
ax = df.plot(kind='bar')
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
# Costumize our plot with the set()
ax = df.plot(kind='bar')
ax.set(title="Random Number Bar Graph fro DataFrame",
      xlabel='Row Number',
      ylabel = 'Random number')
ax.legend().set_visible(True)

# %%
plt.style.use('seaborn-v0_8-whitegrid')

# OO method from scratch
fix,ax = plt.subplots(figsize=(10,6))
# plot the data
scatter = ax.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"],
                    cmap='winter');# this changes the color
# Customize
ax.set(title = "Heart Disease and Cholestrol Levels",
      xlabel = "Age",
      ylabel="Cholestrol");
# ADD a legend
ax.legend(*scatter.legend_elements(),title="Target")
#Add a horizontal line
ax.axhline(over50["chol"].mean(),
           linestyle='--')

# %%
# Costumizind y and x axs limitations
# Subplot of chol,age,thalch
fig,(ax0,ax1)=plt.subplots(nrows=2,
                          ncols=1,
                          figsize=(10,10),
                           sharex=True)
# Add data to ax0
scatter = ax0.scatter(x=over50["age"],
                     y=over50["chol"],
                     c=over50["target"],
                     cmap='winter')
ax0.set(title="Heart Disease and Cholestrol levels",
       ylabel='Cholestrol')
ax0.legend(*scatter.legend_elements(),title="Target")
ax0.axhline(over50["chol"].mean(),
           linestyle='--')
# Change the xaxis limits
ax0.set_xlim([50,80])

# Add data to ax1
scatter = ax1.scatter(x=over50["age"],
                     y=over50["thalach"],
                     c=over50["target"],
                     cmap='winter')
ax1.set(title="Heart Disease and Max Heart rate",
       xlabel="Age",
       ylabel="Max Heart Rate");
ax1.set_xlim([50,80])
ax1.set_ylim([60,200])

ax1.legend(*scatter.legend_elements(),title="target")
ax1.axhline(y=over50["thalach"].mean(),
           linestyle='--');


fig.suptitle("Heart Disease Analysis",
             fontsize=16,
             fontweight="bold");

# %%
fig

# %%
fig.savefig("Heartdiseasecodesavedplot.png")
